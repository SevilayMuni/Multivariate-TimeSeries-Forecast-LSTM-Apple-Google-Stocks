# %% [markdown]
# <div style="background: linear-gradient(45deg,  #ff7a5a, #567d9c, #90a3b4); padding: 18px; border-radius: 10px; text-align: center; background-color: black; color: black;"> <h1 style="font-size: 32px;"> LSTM for APPLE STOCK FORECASTING</h1>
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(45deg, #567d9c, #90a3b4); padding: 18px; border-radius: 20px; text-align: center; background-color: black; color: black;"> <h1 style="font-size: 24px;"> Setting To Obtain Stable Results</h1>
#
# </div>

# %%
import tensorflow as tf
import os
import numpy as np
import random

SEED = 0
# Out:
# 2024-09-06 17:46:20.013081: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def set_seeds(seed = SEED):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)

# %%
def set_global_determinism(seed = SEED):
    set_seeds(seed = seed)

    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    
    tf.config.threading.set_inter_op_parallelism_threads(1)
    tf.config.threading.set_intra_op_parallelism_threads(1)

# Call the above function with seed value
set_global_determinism(seed = SEED)

# %% [markdown]
# ## Important !
#
# 1. Please run cells above before executing any other code.
# 2. Model training might become slower since the code is deterministic -- a tradeoff.
# 3. The code belongs to stack overflow user Dan to [Question](https://stackoverflow.com/questions/36288235/how-to-get-stable-results-with-tensorflow-setting-random-seed)

# %% [markdown]
# <div style="background: linear-gradient(45deg, #567d9c, #90a3b4); padding: 15px; border-radius: 20px; text-align: center; background-color: black; color: black;"> <h1 style="font-size: 24px;"> Importing Libraries</h1>
#
# </div>

# %%
# Following commands might be needed for installations. Restart kernel after installations!

# conda install -c anaconda pandas-datareader
# !pip install yfinance
# !pip install pandas-ta

# %%
# Import libraries
import pandas as pd
import numpy as np
import pandas_ta

import matplotlib.pyplot as plt
import seaborn as sns

# For reading stock data from yahoo
import pandas_datareader as pdr
import yfinance as yf

# For time stamps
from datetime import datetime

# For scaler and model evaluation
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error, r2_score

# For model building
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
from keras.models import load_model
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# <div style="background: linear-gradient(45deg, #567d9c, #90a3b4); padding: 15px; border-radius: 20px; text-align: center; background-color: black; color: black;"> <h1 style="font-size: 24px;"> Downloading Dataset from Yahoo Finance </h1>
#
# </div>

# %% [markdown]
# ## !!! Dataset preparation and feature engineering won't be executed in this final notebook version since dataset has been already produced and saved previously.

# %% [markdown]
# ### Information on Dataset:
# Variables:
# - Open: the price when market opened in the morning.
# - Close: the price when market closed in the afternoon.
# - High: the highest price during that trading day.
# - Low: the lowest price during that trading day.
# - Volume: stock's number of shares traded that day. For instance, the stock trading volume would refer to the number of shares of security traded between its daily open and close. Trading volume, and changes to volume over the course of time, are important inputs for technical traders.
# - Adj Close (Adjusted Close): price adjusted to make prices comparable over time. It is standard benchmark utilized by investors to track share's performance over time.

# %%
# Determine end and start dates for dataset download
end = datetime.now()
start = datetime(end.year - 20, end.month, end.day)

# Download Apple's dataset btw 2004 - 2024
df_apple = yf.download('AAPL', start, end)
df_apple

# %%
# Rename columns of Apple DF
column_dict = {'Open': 'open', 'High' : 'high', 'Low' : 'low',
               'Close' : 'close', 'Adj Close' : 'adj_close', 'Volume' : 'volume'}

df_apple = df_apple.rename(columns = column_dict)
df_apple.index.names = ['date']
df_apple.head(5)

# %% [markdown]
# <div style="background: linear-gradient(45deg, #567d9c, #90a3b4); padding: 15px; border-radius: 20px; text-align: center; background-color: black; color: black;"> <h1 style="font-size: 24px;"> Feature Engineering based on Domain Knowledge </h1>
#
# </div>

# %% [markdown]
# Various established technical indicators have been utilized by domain experts to analyze performance of shares.
# Garman-Klass Volatility, RSI, Bollinger Bands, ATR, MACD, Dollar Volume can be given as technical indicator examples. Since we want to forecast closing price of the share of interest, we will utilize only relevant technical indicators: Garman-Klass Volatility, Dollar Volume. In addition, we will calculate rolling sums.
#
# 1. Garman Klass is a volatility estimator that incorporates open, low, high, and close prices of a security. Therefore, our new feature will account for several variables.
# 2. Dollar Volume is simply the number of shares traded multiplied by the price. It is an alternative version of volume designed to account for money flowing into and out of an asset on a particular day.
# 3. On-balance volume (OBV) is a simple accumulation-distribution tool that tallies up and down volume, creating a smooth indicator line to predict when major market moves might occur based on changes in relative trading volume. OBV works best when testing around major highs and lows to measure for possible breakouts and breakdowns. Investors can use OBV to provide many key predictions, such as a bullish divergence predicting the price will break resistance or a bearish divergence predicting a rally will stall or reverse.
# 3. Moving average convergence/divergence (MACD) is a technical indicator to help investors identify market entry points for buying or selling. The MACD line is calculated by subtracting the 26-period exponential moving average (EMA) from the 12-period EMA.
# 4. The moving average (MA) is a simple technical analysis tool that smooths out price data by creating a constantly updated average price. The average is taken over a specific period of time, like 10 days, 20 minutes, 30 weeks, or any time period the trader chooses.

# %%
# Calculate Garman Klass Volatility
df_apple['garman_klass_volatility'] = ((np.log(df_apple['high']) - 
                                    np.log(df_apple['low']))**2)/2 -(
    2*np.log(2)-1)*((np.log(df_apple['adj_close'])-np.log(df_apple['open']))**2)

df_apple.head()

# %%
# Create dollar volume column
df_apple['dollar_volume'] = (df_apple['adj_close'] * df_apple['volume'])/1e6

# Check whether column creations went smoothly
print(df_apple.columns)

# %%
# Define function to calculate 'On Balance Volume (OBV)'
def On_Balance_Volume(Close, Volume):
    change = Close.diff()
    OBV = np.cumsum(np.where(change > 0, Volume, np.where(change < 0, -Volume, 0)))
    return OBV

# Create OBV column
obv = On_Balance_Volume(df_apple['close'], df_apple['volume'])
df_apple['obv'] = obv

# %%
# Calculate the MACD

df_apple['macd'] = df_apple['close'].ewm(
    span = 12, adjust = False).mean() - df_apple['close'].ewm(
    span = 26, adjust = False).mean()
df_apple.head(5)

# %%
# Create rolling sum for certain time periods(see ma_day list) 

ma_day = [3, 5, 10, 12, 20]

for ma in ma_day:
        column_name = f'ma_{ma}_days'
        df_apple[column_name] = df_apple['adj_close'].rolling(ma).mean()

# Check DF after feature engineering process
df_apple.tail()

# %%
# Save csv file 
df_apple.to_csv('apple-stock-price-20-yr-copy.csv')

# %%
# Load dataset from my local disc and state index column
df_apple = pd.read_csv('apple-stock-price-20-yr-copy.csv', index_col = 'date')
df_apple.head(5)
# Out:
#                 open      high       low     close  adj_close     volume  \
# date
# 2004-08-23  0.551071  0.558393  0.546429  0.555000   0.468684  254660000
# 2004-08-24  0.558214  0.570536  0.556964  0.570536   0.481804  374136000
# 2004-08-25  0.569107  0.591964  0.566607  0.590179   0.498392  505618400
# 2004-08-26  0.590000  0.628214  0.584643  0.618929   0.522670  955858400
# 2004-08-27  0.619286  0.620714  0.607143  0.613393   0.517995  388813600
#
#             garman_klass_volatility  dollar_volume         obv      macd  \
# date
# 2004-08-23                -0.009895     119.354958           0  0.000000
# 2004-08-24                -0.008081     180.260104   374136000  0.001239
# 2004-08-25                -0.005842     251.995963   879754400  0.003763
# 2004-08-26                -0.003088     499.598767  1835612800  0.007991
# 2004-08-27                -0.012078     201.403663  1446799200  0.010771
#
#             ma_3_days  ma_5_days  ma_10_days  ma_12_days  ma_20_days
# date
# 2004-08-23        NaN        NaN         NaN         NaN         NaN
# 2004-08-24        NaN        NaN         NaN         NaN         NaN
# 2004-08-25   0.482960        NaN         NaN         NaN         NaN
# 2004-08-26   0.500955        NaN         NaN         NaN         NaN
# 2004-08-27   0.513019   0.497909         NaN         NaN         NaN

# %%
# Cast DF index as datetime 
df_apple.index = pd.to_datetime(df_apple.index)

# %%
# Get general information on DF
print(df_apple.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5034 entries, 2004-08-23 to 2024-08-21
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   open                     5034 non-null   float64
#  1   high                     5034 non-null   float64
#  2   low                      5034 non-null   float64
#  3   close                    5034 non-null   float64
#  4   adj_close                5034 non-null   float64
#  5   volume                   5034 non-null   int64
#  6   garman_klass_volatility  5034 non-null   float64
#  7   dollar_volume            5034 non-null   float64
#  8   obv                      5034 non-null   int64
#  9   macd                     5034 non-null   float64
#  10  ma_3_days                5032 non-null   float64
#  11  ma_5_days                5030 non-null   float64
#  12  ma_10_days               5025 non-null   float64
#  13  ma_12_days               5023 non-null   float64
#  14  ma_20_days               5015 non-null   float64
# dtypes: float64(13), int64(2)
# memory usage: 629.2 KB
# None

# %% [markdown]
# ### Comments:
# 1. The data is numeric and DataFrame (DF) has datetime index.
# 2. Weekends are missing from the records due to closing of stock markets.
# 3. DF has no null values.

# %% [markdown]
# <div style="background: linear-gradient(45deg,  #ff7a5a, #567d9c, #90a3b4); padding: 18px; border-radius: 10px; text-align: center; background-color: black; color: black;"> <h1 style="font-size: 32px;"> DATA VISUALIZATION: TRENDS & RELATIONS</h1>
#
# </div>

# %% [markdown]
# ### Hence plotting 20 years challenges the interpretation of the stock's performance and movement over time; graphs will be plotted seperately based on time intervals.
#
# ***
# **interval 1** = 2004-2008
#
# **interval 2** = 2008-2012 -- *real estate crisis & recovery*
#
# **interval 3** = 2012-2019 -- *till emergence of Covid-19*
#
# **interval 4** = 2019-2022 -- *Covid-19 period*
#
# **interval 5** = 2022-2024 -- *post Covid-19 & recovery period*
# ***

# %%
# Historical view on Adjusted Closing Prices during certain intervals (see code)

sns.set_style('whitegrid')
fig, axs = plt.subplots(2, 1, figsize = (12, 9))

axs[0].plot(df_apple.loc['2007': '2010', 'adj_close'])
axs[0].set_title('Apple Stock In Pre & Real Estate Crisis (2006 & 2010)',
                 fontsize = 15, fontweight = 'bold', pad = 12)
axs[0].axvline(x = pd.to_datetime('2008-01'), color = 'red', linestyle = '--', label = 'Year 2008')

axs[1].plot(df_apple.loc['2018': '2022', 'adj_close'])
axs[1].set_title('Apple Stock In Pre & Covid-19 Era (2019 & 2022)',
                 fontsize = 15, fontweight = 'bold', pad = 12)
axs[1].axvline(x = pd.to_datetime('2020-03'), color = 'red', linestyle = '--', label = 'CRISIS')

for ax in axs.flat:
    ax.set(ylabel = 'Adjusted Closing Price')


plt.tight_layout()
plt.legend()
sns.despine()
plt.show()

# %% [markdown]
# ## Remarks:
#    - After well establish of 2008 economic crisis apple stock price severely declined. It hit the lowest point in first half of 2009.
#    - Apple stock price affected by covid-19 pandemic in a lesser extend compare to real estate crisis.

# %%
sns.set_style('whitegrid')
fig, axs = plt.subplots(1, 2, figsize = (14, 6), layout = 'constrained', sharey = True)

axs[0].plot(df_apple.loc['2006': '2009', 'garman_klass_volatility'])
axs[0].set_title('Real Estate Crisis (2006 & 09)', fontsize = 16, fontweight = 'bold', pad = 12)
axs[0].axvline(x = pd.to_datetime('2008-01'), color = 'red', linestyle = '--', label = 'Year 2008')

axs[1].plot(df_apple.loc['2019': '2022', 'garman_klass_volatility'])
axs[1].set_title('Covid-19 Era (2019 & 22)', fontsize = 16, fontweight = 'bold', pad = 12)
axs[1].axvline(x = pd.to_datetime('2020-03'), color = 'red', linestyle = '--', label = 'CRISIS')

for ax in axs.flat:
    ax.set(ylabel = 'Garman Klass Volatility')

sns.despine()  
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize = (14, 6), layout = 'constrained', sharey = True)

axs[0].plot(df_apple.loc['2006': '2009', 'dollar_volume'], 'tab:green')
axs[0].set_title('Real Estate Crisis (2006 & 09)', fontsize = 16, fontweight = 'bold', pad = 12)
axs[0].axvline(x = pd.to_datetime('2008-01'), color = 'red', linestyle = '--', label = 'Year 2008')

axs[1].plot(df_apple.loc['2019': '2022', 'dollar_volume'], 'tab:green')
axs[1].set_title('Covid-19 Era (2019 & 22)', fontsize = 16, fontweight = 'bold', pad = 12)
axs[1].axvline(x = pd.to_datetime('2020-03'), color = 'red', linestyle = '--', label = 'CRISIS')

fig.suptitle('Historical View on Apple Stock Volumes',
             fontsize = 20, fontweight = 'bold')

for ax in axs.flat:
    ax.set(ylabel = 'Dollar Volume ')

sns.despine()
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(3, 1, figsize = (12, 15), layout = 'constrained')

axs[0].plot(df_apple.loc['2005': '2010', 'obv'], color = 'navy')
axs[0].set_title('Real Estate Crisis (2005 & 10)', fontsize = 16, fontweight = 'bold', pad = 12)
axs[0].axvline(x = pd.to_datetime('2008-01'), color = 'red', linestyle = '--', label = 'Year 2008')

axs[1].plot(df_apple.loc['2011': '2016', 'obv'], color = 'navy')
axs[1].set_title('Recovery Era (2011 & 16)', fontsize = 16, fontweight = 'bold', pad = 12)
axs[1].axvline(x = pd.to_datetime('2013-01'), color = 'red', linestyle = '--', label = 'Year 2008')

axs[2].plot(df_apple.loc['2018': '2023', 'obv'], color = 'navy')
axs[2].set_title('Pre & Post Covid-19 Era (2018 & 23)', fontsize = 16, fontweight = 'bold', pad = 12)
axs[2].axvline(x = pd.to_datetime('2020-03'), color = 'red', linestyle = '--', label = 'CRISIS')

fig.suptitle('Historical View on Apple On-Balance Volume',
             fontsize = 20, fontweight = 'bold')

for ax in axs.flat:
    ax.set(ylabel = 'On-balance volume (OBV) ')

sns.despine()
plt.legend()
plt.show()

# %% [markdown]
# Remarks:
# Second, the growth of Apple's biggest and most profitable product, the iPhone, has hit a wall. Last quarter, iPhone sales grew only 7%, which was well below the estimated 30% growth rate for the smartphone industry as a whole. The growth of smartphone market has now moved out of rich developed markets and into poorer emerging markets. Apple's distribution is limited in these markets, and its products are simply too expensive to compete.
#
# [Reference](https://www.businessinsider.com/two-charts-show-why-apple-stock-dropped-2013-4)

# %%
sns.set_style('white')

fig, ax1 = plt.subplots(figsize = (9, 6))
ax2 = ax1.twinx()

ax1.plot(df_apple.loc['2006': '2010', 'obv'], color = 'maroon', lw = 1.7)
ax2.plot(df_apple.loc['2006': '2010', 'adj_close'], color = 'royalblue', lw = 1.7)

ax1.set_ylabel('On-Balance Volume', color = 'maroon', fontsize = 12)
ax1.tick_params(axis = 'y', labelcolor = 'maroon')

ax2.set_ylabel('Adjusted Closing Price($)', color = 'royalblue', fontsize = 12)
ax2.tick_params(axis = 'y', labelcolor='royalblue')

fig.suptitle('Apple Stock: On-Balance Volume vs Closing Price (2006 & 10)', fontweight = 'bold', fontsize = 18)
fig.autofmt_xdate()

plt.show()

# %%
sns.set_style('white')

fig, ax1 = plt.subplots(figsize = (9, 6))
ax2 = ax1.twinx()

ax1.plot(df_apple.loc['2019': '2023', 'obv'], color = 'maroon', lw = 1.7)
ax2.plot(df_apple.loc['2019': '2023', 'adj_close'], color = 'royalblue', lw = 1.7)

ax1.set_ylabel('On-Balance Volume', color = 'maroon', fontsize = 12)
ax1.tick_params(axis = 'y', labelcolor = 'maroon')

ax2.set_ylabel('Adjusted Closing Price($)', color = 'royalblue', fontsize = 12)
ax2.tick_params(axis = 'y', labelcolor='royalblue')

fig.suptitle('Apple Stock: On-Balance Volume vs Closing Price (2019 & 23)', fontweight = 'bold', fontsize = 16)
fig.autofmt_xdate()

plt.show()

# %%
df_apple.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'adj_close', 'volume',
#        'garman_klass_volume', 'dollar_volume', 'obv', 'macd', 'ma_3_days',
#        'ma_5_days', 'ma_10_days', 'ma_12_days', 'ma_20_days'],
#       dtype='object')

# %%
sns.set_style('white')

fig, ax1 = plt.subplots(figsize = (9, 6))
ax2 = ax1.twinx()

ax1.plot(df_apple.loc['2006': '2010', 'dollar_volume'], color = 'forestgreen', lw = 1.2)
ax2.plot(df_apple.loc['2006': '2010', 'ma_3_days'], color = 'royalblue', lw = 1.7)

ax1.set_ylabel('Dollar Volume', color = 'forestgreen', fontsize = 12)
ax1.tick_params(axis = 'y', labelcolor = 'forestgreen')

ax2.set_ylabel('Moving Avg Closing Price($)', color = 'royalblue', fontsize = 12)
ax2.tick_params(axis = 'y', labelcolor='royalblue')

fig.suptitle('Apple Stock: Dollar Volume vs 3 Days Moving Avg (2006 & 10)', fontweight = 'bold', fontsize = 16)
fig.autofmt_xdate()

plt.show()

# %%
sns.set_style('white')

fig, ax1 = plt.subplots(figsize = (9, 6))
ax2 = ax1.twinx()

ax1.plot(df_apple.loc['2019': '2023', 'dollar_volume'], color = 'forestgreen', lw = 1.2)
ax2.plot(df_apple.loc['2019': '2023', 'ma_3_days'], color = 'royalblue', lw = 1.7)

ax1.set_ylabel('Dollar Volume', color = 'forestgreen', fontsize = 12)
ax1.tick_params(axis = 'y', labelcolor = 'forestgreen')

ax2.set_ylabel('Moving Avg Closing Price($)', color = 'royalblue', fontsize = 12)
ax2.tick_params(axis = 'y', labelcolor='royalblue')

fig.suptitle('Apple Stock: Dollar Volume vs 3 Days Moving Avg (2019 & 23)', fontweight = 'bold', fontsize = 16)
fig.autofmt_xdate()

plt.show()

# %%
sns.set_style('white')

fig, ax1 = plt.subplots(figsize = (9, 5))
ax2 = ax1.twinx()

ax1.plot(df_apple.loc['2019': '2023', 'open'], color = 'coral', lw = 1.7)
ax2.plot(df_apple.loc['2019': '2023', 'adj_close'], color = 'royalblue', lw = 1.7)

ax1.set_ylabel('Opening Price($)', color = 'coral', fontsize = 12)
ax1.tick_params(axis = 'y', labelcolor = 'coral')

ax2.set_ylabel('Adjusted Closing Price($)', color = 'royalblue', fontsize = 12)
ax2.tick_params(axis = 'y', labelcolor = 'royalblue')

fig.suptitle('Apple Stock: Opening vs Closing Prices (2019 & 23)', fontweight = 'bold', fontsize = 18)
fig.autofmt_xdate()

plt.show()

# %%
# Use narrow timeline to assess which MA period reflects smoothly and accurately daily adj. closing price!

fig, axs = plt.subplots(2, figsize = (10, 8), layout = 'constrained')

df_apple.loc['2010-01': '2010-12', ['adj_close', 'ma_3_days',
                                    'ma_5_days', 'ma_10_days',
                                    'ma_12_days', 'ma_20_days']].plot(ax = axs[0])
axs[0].set_title('Apple')

df_apple.loc['2021-01': '2021-12', ['adj_close', 'ma_3_days',
                                    'ma_5_days', 'ma_10_days',
                                    'ma_12_days', 'ma_20_days']].plot(ax = axs[1])
axs[1].set_title('Apple')
plt.show()

# %%
sns.heatmap(df_apple[['open', 'high', 'low', 'close', 'adj_close', 
                      'volume', 'garman_klass_volume', 'dollar_volume', 
                      'obv', 'macd', 'ma_3_days', 'ma_5_days']].corr(), 
            annot = True, cbar = False, cmap = 'Blues', fmt = '.1f')

plt.title('Apple Heatmap', fontsize = 14, fontweight = 'bold')
plt.show()

# %%
apple_features = ['adj_close', 'garman_klass_volume', 'dollar_volume', 'obv', 'ma_3_days']
apple_dset = df_apple.filter(apple_features)
apple_dset.dropna(axis = 0, inplace = True)
print(apple_dset.shape)
# Out:
# (5032, 5)

# %%
q_80 = int(len(apple_dset) * 0.8)

apple_train = apple_dset[:q_80]
apple_test = apple_dset[q_80:]

apple_train.shape, apple_test.shape
# Out:
# ((4025, 5), (1007, 5))

# %%
scaler = MinMaxScaler(feature_range = (0, 1))
apple_train_scaled = scaler.fit_transform(apple_train)
apple_test_scaled = scaler.transform(apple_test)
apple_train_scaled
# Out:
# array([[5.77393708e-05, 2.71242550e-01, 2.94309967e-03, 4.43901398e-03,
#         6.00773026e-05],
#        [7.73716422e-05, 3.21104929e-01, 1.27107910e-03, 7.73734592e-03,
#         6.43983712e-05],
#        [4.50398949e-05, 2.76814918e-01, 6.56031944e-04, 4.90194270e-03,
#         3.45569081e-05],
#        ...,
#        [9.61537759e-01, 5.78860817e-01, 6.67971736e-01, 9.11262926e-01,
#         9.59889965e-01],
#        [1.00000000e+00, 5.72967244e-01, 4.66732632e-01, 9.12790832e-01,
#         9.83224426e-01],
#        [9.79197268e-01, 6.00214169e-01, 6.02805015e-01, 9.10778546e-01,
#         1.00000000e+00]])

# %%
def createXY(dataset, n_past):
    dataX = []
    dataY = []
    for i in range(n_past, len(dataset)):
            dataX.append(dataset[i - n_past:i, 0:dataset.shape[1]])
            dataY.append(dataset[i,0])
    return np.array(dataX),np.array(dataY)

trainX, trainY = createXY(apple_train_scaled, 21)
testX, testY = createXY(apple_test_scaled, 21)

# %%
trainX.shape, trainY.shape, testX.shape, testY.shape
# Out:
# ((4004, 21, 5), (4004,), (986, 21, 5), (986,))

# %%
def build_model(optimizer):
    grid_model = Sequential()
    grid_model.add(LSTM(60, return_sequences = True, input_shape = (21, 5)))
    grid_model.add(LSTM(60))
    grid_model.add(Dropout(0.1))
    grid_model.add(Dense(1))
    grid_model.compile(loss = 'mse', optimizer = optimizer)
    return grid_model


grid_model = KerasRegressor(build_fn = build_model,
                            verbose = 1, validation_data = (testX, testY))
parameters = {'batch_size' : [20, 26],
              'epochs' : [15, 20],
              'optimizer' : ['adam', 'Adadelta']}
grid_search  = GridSearchCV(estimator = grid_model,
                            param_grid = parameters,
                            cv = 4)
# Out:
# /var/folders/k6/rj6vyp8j659d9vfskgxrz_x40000gn/T/ipykernel_8191/424498336.py:11: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   grid_model = KerasRegressor(build_fn = build_model,

# %%
grid_search = grid_search.fit(trainX, trainY)
# Out:
# 2024-09-06 14:35:09.011101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:35:09.013926: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:35:09.015577: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:35:09.194307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:35:09.195584: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:35:09.197015: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/15
# 2024-09-06 14:35:09.367018: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:35:09.367747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:35:09.800364: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:35:09.803000: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:35:09.805081: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:35:10.323431: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:35:10.325912: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:35:10.328155: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:35:11.875125: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:35:11.877350: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:35:11.879277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:35:12.078684: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:35:12.081690: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:35:12.084251: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 150/151 [============================>.] - ETA: 0s - loss: 0.0034
# 2024-09-06 14:35:17.937841: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:35:17.938129: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:35:18.222086: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:35:18.224749: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:35:18.227288: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:35:18.471080: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:35:18.474711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:35:18.477543: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 151/151 [==============================] - 9s 26ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 2/15
# 151/151 [==============================] - 3s 23ms/step - loss: 4.3048e-04 - val_loss: 0.0093
# Epoch 3/15
# 151/151 [==============================] - 3s 20ms/step - loss: 3.8507e-04 - val_loss: 0.0172
# Epoch 4/15
# 151/151 [==============================] - 3s 22ms/step - loss: 3.5913e-04 - val_loss: 0.0052
# Epoch 5/15
# 151/151 [==============================] - 5s 30ms/step - loss: 3.0827e-04 - val_loss: 0.0044
# Epoch 6/15
# 151/151 [==============================] - 4s 27ms/step - loss: 2.8373e-04 - val_loss: 0.0051
# Epoch 7/15
# 151/151 [==============================] - 3s 21ms/step - loss: 2.8319e-04 - val_loss: 0.0575
# Epoch 8/15
# 151/151 [==============================] - 3s 21ms/step - loss: 3.7210e-04 - val_loss: 0.0016
# Epoch 9/15
# 151/151 [==============================] - 3s 22ms/step - loss: 3.4342e-04 - val_loss: 0.0016
# Epoch 10/15
# 151/151 [==============================] - 3s 21ms/step - loss: 2.3802e-04 - val_loss: 0.0019
# Epoch 11/15
# 151/151 [==============================] - 3s 21ms/step - loss: 2.2763e-04 - val_loss: 0.0084
# Epoch 12/15
# 151/151 [==============================] - 4s 25ms/step - loss: 2.1144e-04 - val_loss: 0.0018
# Epoch 13/15
# 151/151 [==============================] - 3s 22ms/step - loss: 2.3433e-04 - val_loss: 0.0041
# Epoch 14/15
# 151/151 [==============================] - 3s 22ms/step - loss: 2.2123e-04 - val_loss: 0.0045
# Epoch 15/15
# 151/151 [==============================] - 3s 22ms/step - loss: 1.8286e-04 - val_loss: 0.0022
#  9/51 [====>.........................] - ETA: 0s - loss: 1.6894e-05
# 2024-09-06 14:36:07.087872: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:36:07.088254: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 51/51 [==============================] - 0s 8ms/step - loss: 6.4527e-06
# 2024-09-06 14:36:07.824670: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:36:07.826770: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:36:07.828414: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/15
# 2024-09-06 14:36:08.128840: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:36:08.130896: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:36:08.132277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:36:08.206904: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:36:08.207216: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:36:08.707267: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:36:08.717612: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:36:08.722573: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:36:09.017387: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:36:09.019507: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:36:09.021512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:36:10.354824: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:36:10.357239: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:36:10.359130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:36:10.571070: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:36:10.573011: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:36:10.574492: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 151/151 [==============================] - ETA: 0s - loss: 0.0026
# 2024-09-06 14:36:15.024179: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:36:15.024501: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:36:15.285400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:36:15.287756: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:36:15.289927: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:36:15.555240: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:36:15.558189: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:36:15.560918: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 151/151 [==============================] - 8s 26ms/step - loss: 0.0026 - val_loss: 0.0090
# Epoch 2/15
# 151/151 [==============================] - 3s 22ms/step - loss: 4.5280e-04 - val_loss: 0.0032
# Epoch 3/15
# 151/151 [==============================] - 3s 23ms/step - loss: 3.2793e-04 - val_loss: 0.0107
# Epoch 4/15
# 151/151 [==============================] - 3s 21ms/step - loss: 3.7823e-04 - val_loss: 0.0098
# Epoch 5/15
# 151/151 [==============================] - 3s 22ms/step - loss: 2.9318e-04 - val_loss: 0.0028
# Epoch 6/15
# 151/151 [==============================] - 3s 22ms/step - loss: 2.5162e-04 - val_loss: 0.0126
# Epoch 7/15
# 151/151 [==============================] - 3s 21ms/step - loss: 2.7107e-04 - val_loss: 0.0243
# Epoch 8/15
# 151/151 [==============================] - 3s 21ms/step - loss: 3.0778e-04 - val_loss: 0.0025
# Epoch 9/15
# 151/151 [==============================] - 4s 24ms/step - loss: 2.9940e-04 - val_loss: 0.0017
# Epoch 10/15
# 151/151 [==============================] - 3s 21ms/step - loss: 2.4929e-04 - val_loss: 0.0014
# Epoch 11/15
# 151/151 [==============================] - 3s 22ms/step - loss: 2.1980e-04 - val_loss: 0.0103
# Epoch 12/15
# 151/151 [==============================] - 3s 21ms/step - loss: 2.1016e-04 - val_loss: 0.0019
# Epoch 13/15
# 151/151 [==============================] - 4s 24ms/step - loss: 2.2295e-04 - val_loss: 0.0027
# Epoch 14/15
# 151/151 [==============================] - 3s 21ms/step - loss: 2.3559e-04 - val_loss: 0.0018
# Epoch 15/15
# 151/151 [==============================] - 3s 22ms/step - loss: 1.9919e-04 - val_loss: 0.0012
# 31/51 [=================>............] - ETA: 0s - loss: 3.9819e-06
# 2024-09-06 14:37:02.472078: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:37:02.472538: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 51/51 [==============================] - 0s 6ms/step - loss: 1.9240e-05
# 2024-09-06 14:37:03.000709: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:37:03.002668: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:37:03.004128: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/15
# 2024-09-06 14:37:03.214634: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:37:03.216661: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:37:03.218335: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:37:03.296363: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:37:03.296686: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:37:03.596193: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:37:03.597943: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:37:03.599910: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:37:03.882415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:37:03.885097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:37:03.886989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:37:05.408526: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:37:05.410646: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:37:05.413006: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:37:05.715467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:37:05.717649: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:37:05.719544: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 149/151 [============================>.] - ETA: 0s - loss: 0.0026
# 2024-09-06 14:37:12.558469: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:37:12.558782: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:37:12.970996: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:37:12.973570: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:37:12.975938: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:37:13.244703: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:37:13.247257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:37:13.249639: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 151/151 [==============================] - 10s 33ms/step - loss: 0.0026 - val_loss: 0.0045
# Epoch 2/15
# 151/151 [==============================] - 3s 21ms/step - loss: 4.3262e-04 - val_loss: 0.0101
# Epoch 3/15
# 151/151 [==============================] - 3s 21ms/step - loss: 4.0124e-04 - val_loss: 0.0047
# Epoch 4/15
# 151/151 [==============================] - 4s 23ms/step - loss: 3.5123e-04 - val_loss: 0.0042
# Epoch 5/15
# 151/151 [==============================] - 4s 24ms/step - loss: 3.1528e-04 - val_loss: 0.0021
# Epoch 6/15
# 151/151 [==============================] - 3s 22ms/step - loss: 2.3250e-04 - val_loss: 0.0044
# Epoch 7/15
# 151/151 [==============================] - 3s 21ms/step - loss: 2.3791e-04 - val_loss: 0.0237
# Epoch 8/15
# 151/151 [==============================] - 3s 21ms/step - loss: 2.8145e-04 - val_loss: 0.0015
# Epoch 9/15
# 151/151 [==============================] - 3s 21ms/step - loss: 3.0444e-04 - val_loss: 0.0016
# Epoch 10/15
# 151/151 [==============================] - 3s 21ms/step - loss: 2.0636e-04 - val_loss: 0.0014
# Epoch 11/15
# 151/151 [==============================] - 4s 27ms/step - loss: 2.0561e-04 - val_loss: 0.0039
# Epoch 12/15
# 151/151 [==============================] - 3s 21ms/step - loss: 2.1082e-04 - val_loss: 0.0017
# Epoch 13/15
# 151/151 [==============================] - 3s 21ms/step - loss: 2.1831e-04 - val_loss: 0.0017
# Epoch 14/15
# 151/151 [==============================] - 3s 21ms/step - loss: 2.0534e-04 - val_loss: 0.0039
# Epoch 15/15
# 151/151 [==============================] - 4s 25ms/step - loss: 1.6762e-04 - val_loss: 0.0013
# 31/51 [=================>............] - ETA: 0s - loss: 4.2231e-05
# 2024-09-06 14:38:00.577473: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:38:00.577800: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 51/51 [==============================] - 0s 5ms/step - loss: 4.2088e-05
# 2024-09-06 14:38:01.087241: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:38:01.089018: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:38:01.090823: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/15
# 2024-09-06 14:38:01.299328: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:38:01.301192: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:38:01.302674: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:38:01.386785: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:38:01.387118: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 14:38:01.669283: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:38:01.671038: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:38:01.673282: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:38:01.935663: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:38:01.937315: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:38:01.939050: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:38:03.079993: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:38:03.082273: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:38:03.084168: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 14:38:03.332805: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 14:38:03.335180: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 14:38:03.337561: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 149/151 [============================>.] - ETA: 0s - loss: 4.3181e-04
# 2024-09-06 14:38:08.080646: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# ...
# 2024-09-06 15:05:35.829967: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:05:35.832382: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 116/116 [==============================] - 7s 29ms/step - loss: 0.0032 - val_loss: 1.1407
# Epoch 2/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0030 - val_loss: 1.1452
# Epoch 3/20
# 116/116 [==============================] - 3s 28ms/step - loss: 0.0028 - val_loss: 1.1466
# Epoch 4/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0029 - val_loss: 1.1455
# Epoch 5/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0028 - val_loss: 1.1427
# Epoch 6/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0028 - val_loss: 1.1394
# Epoch 7/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0028 - val_loss: 1.1344
# Epoch 8/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0027 - val_loss: 1.1297
# Epoch 9/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0027 - val_loss: 1.1252
# Epoch 10/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0027 - val_loss: 1.1207
# Epoch 11/20
# 116/116 [==============================] - 4s 31ms/step - loss: 0.0026 - val_loss: 1.1148
# Epoch 12/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0025 - val_loss: 1.1086
# Epoch 13/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0026 - val_loss: 1.1020
# Epoch 14/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0025 - val_loss: 1.0964
# Epoch 15/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0025 - val_loss: 1.0917
# Epoch 16/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0024 - val_loss: 1.0868
# Epoch 17/20
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0025 - val_loss: 1.0814
# Epoch 18/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0024 - val_loss: 1.0755
# Epoch 19/20
# 116/116 [==============================] - 3s 27ms/step - loss: 0.0024 - val_loss: 1.0695
# Epoch 20/20
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0023 - val_loss: 1.0645
# 28/39 [====================>.........] - ETA: 0s - loss: 0.0294
# 2024-09-06 15:06:29.116650: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:06:29.116972: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0681
# 2024-09-06 15:06:29.566601: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:06:29.568697: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:06:29.570369: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:06:29.756453: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:06:29.758067: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:06:29.759598: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/15
# 2024-09-06 15:06:29.848612: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [4004]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:06:29.848942: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [4004]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:06:30.116122: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:06:30.118136: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:06:30.120272: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:06:30.357438: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:06:30.359820: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:06:30.361596: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:06:31.356125: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:06:31.359310: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:06:31.361760: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:06:31.633014: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:06:31.635300: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:06:31.637388: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 199/201 [============================>.] - ETA: 0s - loss: 0.0019
# 2024-09-06 15:06:37.706593: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:06:37.706925: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:06:37.964695: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:06:37.966944: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:06:37.968758: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:06:38.229915: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:06:38.232139: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:06:38.234160: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 201/201 [==============================] - 9s 24ms/step - loss: 0.0019 - val_loss: 0.0047
# Epoch 2/15
# 201/201 [==============================] - 4s 21ms/step - loss: 3.4583e-04 - val_loss: 0.0062
# Epoch 3/15
# 201/201 [==============================] - 5s 24ms/step - loss: 2.9822e-04 - val_loss: 0.0203
# Epoch 4/15
# 201/201 [==============================] - 4s 21ms/step - loss: 2.6586e-04 - val_loss: 0.0055
# Epoch 5/15
# 201/201 [==============================] - 4s 21ms/step - loss: 2.2338e-04 - val_loss: 0.0122
# Epoch 6/15
# 201/201 [==============================] - 4s 21ms/step - loss: 2.2035e-04 - val_loss: 0.0032
# Epoch 7/15
# 201/201 [==============================] - 4s 21ms/step - loss: 2.3432e-04 - val_loss: 0.0044
# Epoch 8/15
# 201/201 [==============================] - 4s 21ms/step - loss: 2.3503e-04 - val_loss: 0.0074
# Epoch 9/15
# 201/201 [==============================] - 5s 23ms/step - loss: 1.8053e-04 - val_loss: 0.0033
# Epoch 10/15
# 201/201 [==============================] - 4s 21ms/step - loss: 1.8727e-04 - val_loss: 0.0028
# Epoch 11/15
# 201/201 [==============================] - 4s 21ms/step - loss: 1.7337e-04 - val_loss: 0.0055
# Epoch 12/15
# 201/201 [==============================] - 4s 21ms/step - loss: 1.9795e-04 - val_loss: 0.0031
# Epoch 13/15
# 201/201 [==============================] - 4s 22ms/step - loss: 1.4929e-04 - val_loss: 0.0012
# Epoch 14/15
# 201/201 [==============================] - 5s 25ms/step - loss: 1.4993e-04 - val_loss: 0.0032
# Epoch 15/15
# 201/201 [==============================] - 4s 21ms/step - loss: 1.3905e-04 - val_loss: 0.0037

# %%
grid_search.best_params_
# Out:
# {'batch_size': 20, 'epochs': 15, 'optimizer': 'adam'}

# %%
apple_model = grid_search.best_estimator_.model

# %%
apple_model.save('Apple-LSTM-Model-No1.h5')
print('Model is saved to disk :)')
# Out:
# Model is saved to disk :)

# %%
# Generate prediction
prediction = apple_model.predict(testX)

print('Prediction Shape:', prediction.shape)
# Out:
# 2024-09-06 15:12:42.441501: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [986,21,5]
# 	 [[{{node Placeholder/_10}}]]
# 2024-09-06 15:12:42.442049: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [986,21,5]
# 	 [[{{node Placeholder/_10}}]]
# 2024-09-06 15:12:42.872207: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:12:42.875358: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:12:42.877712: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:12:43.080695: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:12:43.082873: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:12:43.084571: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 31/31 [==============================] - 1s 8ms/step
# Prediction Shape: (986, 1)

# %%
# Change shape to use inverse_transform
prediction_array = np.repeat(prediction, 5, axis = -1)
original_array = np.repeat(testY, 5, axis = -1)
prediction_array
# Out:
# array([[0.8738608 , 0.8738608 , 0.8738608 , 0.8738608 , 0.8738608 ],
#        [0.87879056, 0.87879056, 0.87879056, 0.87879056, 0.87879056],
#        [0.88153684, 0.88153684, 0.88153684, 0.88153684, 0.88153684],
#        ...,
#        [1.8080493 , 1.8080493 , 1.8080493 , 1.8080493 , 1.8080493 ],
#        [1.8036122 , 1.8036122 , 1.8036122 , 1.8036122 , 1.8036122 ],
#        [1.7933245 , 1.7933245 , 1.7933245 , 1.7933245 , 1.7933245 ]],
#       dtype=float32)

# %%
# We just need the first column(adj_close) after inverse transform, so use [:,0] at the end
pred = scaler.inverse_transform(np.reshape(prediction_array,(len(prediction), 5)))[:,0]
original = scaler.inverse_transform(np.reshape(original_array,(len(testY), 5)))[:,0]

# %%
# Make sure dataset sizes are consistent
pred.shape, original.shape
# Out:
# ((986,), (986,))

# %%
plt.figure(figsize = (10, 6))
sns.set_style('whitegrid')

plt.plot(original, color = 'midnightblue', label = 'Real Price')
plt.plot(pred, color = 'firebrick', label = 'Predicted Price')
plt.xlabel('Time')
plt.ylabel('Adjusted Closing Price')
plt.title('1st Model: Apple Stock Price Prediction', fontweight = 'bold', fontsize = 16)
plt.legend()

sns.despine()
plt.show()

# %% [markdown]
# ***
# ## Building 2nd Model
# ***

# %%
def build_2_model(optimizer):
    grid_model = Sequential()
    grid_model.add(LSTM(128, return_sequences = True, input_shape = (21, 5)))
    grid_model.add(LSTM(64))
    grid_model.add(Dense(10))
    grid_model.add(Dense(1))
    grid_model.compile(loss = 'mse', optimizer = optimizer)
    return grid_model


grid_model = KerasRegressor(build_fn = build_2_model, verbose = 1, validation_data = (testX, testY))
parameters = {'batch_size' : [16, 20, 26], 'epochs' : [10, 15, 20], 'optimizer' : ['adam', 'Adadelta']}
grid_search  = GridSearchCV(estimator = grid_model, param_grid = parameters, cv = 4)
# Out:
# /var/folders/k6/rj6vyp8j659d9vfskgxrz_x40000gn/T/ipykernel_8191/1421640796.py:11: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   grid_model = KerasRegressor(build_fn = build_2_model, verbose = 1, validation_data = (testX, testY))

# %%
grid_search = grid_search.fit(trainX, trainY)
# Out:
# 2024-09-06 15:14:06.900521: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:14:06.902458: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:14:06.904404: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/10
# 2024-09-06 15:14:07.195881: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:14:07.197496: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:14:07.199226: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:14:07.281093: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [3003,21,5]
# 	 [[{{node Placeholder/_10}}]]
# 2024-09-06 15:14:07.281418: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:14:07.576145: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:14:07.578362: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:14:07.580328: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:14:07.797455: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:14:07.799786: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:14:07.801897: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:14:09.192727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:14:09.194758: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:14:09.196660: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:14:09.417633: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:14:09.419899: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:14:09.421678: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 187/188 [============================>.] - ETA: 0s - loss: 0.0013
# 2024-09-06 15:14:16.916610: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:14:16.916919: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:14:17.336931: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:14:17.339942: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:14:17.342600: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:14:17.694268: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:14:17.698358: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:14:17.700748: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 188/188 [==============================] - 11s 39ms/step - loss: 0.0013 - val_loss: 0.0036
# Epoch 2/10
# 188/188 [==============================] - 7s 35ms/step - loss: 1.9250e-04 - val_loss: 0.0242
# Epoch 3/10
# 188/188 [==============================] - 7s 38ms/step - loss: 2.0118e-04 - val_loss: 0.0024
# Epoch 4/10
# 188/188 [==============================] - 7s 36ms/step - loss: 1.3818e-04 - val_loss: 0.0162
# Epoch 5/10
# 188/188 [==============================] - 7s 38ms/step - loss: 1.9142e-04 - val_loss: 0.0188
# Epoch 6/10
# 188/188 [==============================] - 7s 38ms/step - loss: 1.3100e-04 - val_loss: 0.0065
# Epoch 7/10
# 188/188 [==============================] - 7s 35ms/step - loss: 1.0345e-04 - val_loss: 0.0038
# Epoch 8/10
# 188/188 [==============================] - 7s 37ms/step - loss: 1.1499e-04 - val_loss: 0.0138
# Epoch 9/10
# 188/188 [==============================] - 7s 35ms/step - loss: 1.0398e-04 - val_loss: 0.0092
# Epoch 10/10
# 188/188 [==============================] - 6s 34ms/step - loss: 9.5008e-05 - val_loss: 0.0030
# 25/63 [==========>...................] - ETA: 0s - loss: 5.5229e-05
# 2024-09-06 15:15:19.689031: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:15:19.689359: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 63/63 [==============================] - 0s 7ms/step - loss: 3.6390e-05
# 2024-09-06 15:15:20.341702: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:15:20.343438: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:15:20.345162: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/10
# 2024-09-06 15:15:20.543899: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:15:20.545938: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:15:20.547804: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:15:20.635659: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [3003,21,5]
# 	 [[{{node Placeholder/_10}}]]
# 2024-09-06 15:15:20.635955: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:15:20.910577: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:15:20.913090: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:15:20.914437: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:15:21.134439: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:15:21.136823: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:15:21.139066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:15:22.175119: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:15:22.177343: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:15:22.179554: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:15:22.394456: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:15:22.396493: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:15:22.398344: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 188/188 [==============================] - ETA: 0s - loss: 0.0016
# 2024-09-06 15:15:30.711849: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [986,21,5]
# 	 [[{{node Placeholder/_10}}]]
# 2024-09-06 15:15:30.712200: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:15:30.964831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:15:30.967784: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:15:30.970525: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:15:31.225921: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:15:31.228877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:15:31.231191: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 188/188 [==============================] - 11s 42ms/step - loss: 0.0016 - val_loss: 0.0070
# Epoch 2/10
# 188/188 [==============================] - 7s 35ms/step - loss: 1.7371e-04 - val_loss: 0.0318
# Epoch 3/10
# 188/188 [==============================] - 6s 34ms/step - loss: 1.6951e-04 - val_loss: 0.0096
# Epoch 4/10
# 188/188 [==============================] - 6s 34ms/step - loss: 1.1589e-04 - val_loss: 0.0209
# Epoch 5/10
# 188/188 [==============================] - 6s 34ms/step - loss: 1.8484e-04 - val_loss: 0.0286
# Epoch 6/10
# 188/188 [==============================] - 7s 36ms/step - loss: 1.1631e-04 - val_loss: 0.0077
# Epoch 7/10
# 188/188 [==============================] - 6s 34ms/step - loss: 1.0352e-04 - val_loss: 0.0032
# Epoch 8/10
# 188/188 [==============================] - 7s 37ms/step - loss: 1.0946e-04 - val_loss: 0.0176
# Epoch 9/10
# 188/188 [==============================] - 6s 34ms/step - loss: 1.1044e-04 - val_loss: 0.0085
# Epoch 10/10
# 188/188 [==============================] - 7s 36ms/step - loss: 1.0220e-04 - val_loss: 0.0050
# 25/63 [==========>...................] - ETA: 0s - loss: 1.2057e-05
# 2024-09-06 15:16:31.110805: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:16:31.111372: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 63/63 [==============================] - 0s 7ms/step - loss: 3.1690e-05
# 2024-09-06 15:16:31.797418: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:16:31.799205: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:16:31.800726: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:16:31.988124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:16:31.989330: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:16:31.990692: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/10
# 2024-09-06 15:16:32.086485: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:16:32.086783: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:16:32.367220: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:16:32.369613: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:16:32.371619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:16:32.611435: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:16:32.613581: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:16:32.615365: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:16:33.940335: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:16:33.942663: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:16:33.944390: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:16:34.244105: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:16:34.245615: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:16:34.247323: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 188/188 [==============================] - ETA: 0s - loss: 0.0011
# 2024-09-06 15:16:41.922660: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:16:41.923029: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:16:42.813599: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:16:42.816544: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:16:42.818275: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:16:43.065783: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:16:43.069063: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:16:43.072132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 188/188 [==============================] - 12s 41ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 2/10
# 188/188 [==============================] - 7s 35ms/step - loss: 2.0753e-04 - val_loss: 0.0309
# Epoch 3/10
# 188/188 [==============================] - 6s 34ms/step - loss: 1.6161e-04 - val_loss: 0.0073
# Epoch 4/10
# 188/188 [==============================] - 6s 34ms/step - loss: 1.1530e-04 - val_loss: 0.0159
# Epoch 5/10
# 188/188 [==============================] - 7s 36ms/step - loss: 1.8245e-04 - val_loss: 0.0143
# Epoch 6/10
# 188/188 [==============================] - 7s 35ms/step - loss: 1.0271e-04 - val_loss: 0.0050
# Epoch 7/10
# 188/188 [==============================] - 7s 37ms/step - loss: 9.5176e-05 - val_loss: 0.0029
# Epoch 8/10
# 188/188 [==============================] - 7s 35ms/step - loss: 9.9401e-05 - val_loss: 0.0081
# Epoch 9/10
# 188/188 [==============================] - 7s 35ms/step - loss: 1.1747e-04 - val_loss: 0.0062
# Epoch 10/10
# 188/188 [==============================] - 6s 34ms/step - loss: 8.9386e-05 - val_loss: 0.0023
# 25/63 [==========>...................] - ETA: 0s - loss: 1.6859e-05
# 2024-09-06 15:17:42.953491: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1001,21,5]
# 	 [[{{node Placeholder/_10}}]]
# 2024-09-06 15:17:42.954055: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 63/63 [==============================] - 0s 7ms/step - loss: 2.3695e-05
# 2024-09-06 15:17:43.631830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:17:43.633331: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:17:43.635100: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:17:43.830382: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:17:43.831692: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:17:43.833036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/10
# 2024-09-06 15:17:43.932482: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:17:43.932780: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [3003]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:17:44.323342: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:17:44.325974: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:17:44.328290: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:17:44.652518: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:17:44.654395: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:17:44.656058: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:17:46.071629: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:17:46.074260: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:17:46.076485: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:17:46.421195: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:17:46.423886: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:17:46.426029: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 188/188 [==============================] - ETA: 0s - loss: 3.0316e-04
# 2024-09-06 15:17:54.256563: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:17:54.256947: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 15:17:54.527701: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 15:17:54.530033: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 15:17:54.532377: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 15:17:54.808063: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# ...
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 116/116 [==============================] - 10s 48ms/step - loss: 0.0037 - val_loss: 1.1335
# Epoch 2/20
# 116/116 [==============================] - 5s 42ms/step - loss: 0.0028 - val_loss: 1.0825
# Epoch 3/20
# 116/116 [==============================] - 5s 43ms/step - loss: 0.0025 - val_loss: 1.0483
# Epoch 4/20
# 116/116 [==============================] - 5s 42ms/step - loss: 0.0024 - val_loss: 1.0242
# Epoch 5/20
# 116/116 [==============================] - 6s 50ms/step - loss: 0.0023 - val_loss: 1.0038
# Epoch 6/20
# 116/116 [==============================] - 5s 42ms/step - loss: 0.0022 - val_loss: 0.9829
# Epoch 7/20
# 116/116 [==============================] - 5s 41ms/step - loss: 0.0021 - val_loss: 0.9643
# Epoch 8/20
# 116/116 [==============================] - 5s 46ms/step - loss: 0.0020 - val_loss: 0.9462
# Epoch 9/20
# 116/116 [==============================] - 5s 41ms/step - loss: 0.0019 - val_loss: 0.9289
# Epoch 10/20
# 116/116 [==============================] - 5s 42ms/step - loss: 0.0018 - val_loss: 0.9111
# Epoch 11/20
# 116/116 [==============================] - 5s 41ms/step - loss: 0.0018 - val_loss: 0.8921
# Epoch 12/20
# 116/116 [==============================] - 5s 47ms/step - loss: 0.0017 - val_loss: 0.8749
# Epoch 13/20
# 116/116 [==============================] - 5s 45ms/step - loss: 0.0016 - val_loss: 0.8581
# Epoch 14/20
# 116/116 [==============================] - 5s 45ms/step - loss: 0.0015 - val_loss: 0.8415
# Epoch 15/20
# 116/116 [==============================] - 5s 43ms/step - loss: 0.0015 - val_loss: 0.8259
# Epoch 16/20
# 116/116 [==============================] - 5s 42ms/step - loss: 0.0014 - val_loss: 0.8111
# Epoch 17/20
# 116/116 [==============================] - 5s 42ms/step - loss: 0.0013 - val_loss: 0.7970
# Epoch 18/20
# 116/116 [==============================] - 5s 45ms/step - loss: 0.0013 - val_loss: 0.7819
# Epoch 19/20
# 116/116 [==============================] - 5s 41ms/step - loss: 0.0012 - val_loss: 0.7686
# Epoch 20/20
# 116/116 [==============================] - 6s 50ms/step - loss: 0.0012 - val_loss: 0.7542
# 13/39 [=========>....................] - ETA: 0s - loss: 0.0095
# 2024-09-06 17:07:09.468044: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 17:07:09.468410: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [1001]
# 	 [[{{node Placeholder/_11}}]]
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0456
# 2024-09-06 17:07:10.068434: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 17:07:10.070251: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 17:07:10.072102: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 17:07:10.251625: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 17:07:10.253162: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 17:07:10.254552: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/20
# 2024-09-06 17:07:10.344675: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [4004]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 17:07:10.344994: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [4004]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 17:07:10.628866: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 17:07:10.631130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 17:07:10.632674: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 17:07:10.893735: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 17:07:10.896088: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 17:07:10.897884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 17:07:11.947714: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 17:07:11.949867: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 17:07:11.951883: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 17:07:12.179344: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 17:07:12.183163: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 17:07:12.185498: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 250/251 [============================>.] - ETA: 0s - loss: 0.0012
# 2024-09-06 17:07:22.062727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 17:07:22.063019: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [986]
# 	 [[{{node Placeholder/_11}}]]
# 2024-09-06 17:07:22.331874: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 17:07:22.333891: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 17:07:22.335881: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 17:07:22.593122: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 17:07:22.595423: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 17:07:22.597444: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 251/251 [==============================] - 13s 37ms/step - loss: 0.0012 - val_loss: 0.0196
# Epoch 2/20
# 251/251 [==============================] - 9s 36ms/step - loss: 1.2077e-04 - val_loss: 0.0038
# Epoch 3/20
# 251/251 [==============================] - 9s 35ms/step - loss: 1.4372e-04 - val_loss: 0.0148
# Epoch 4/20
# 251/251 [==============================] - 9s 36ms/step - loss: 1.1674e-04 - val_loss: 0.0090
# Epoch 5/20
# 251/251 [==============================] - 9s 35ms/step - loss: 1.2876e-04 - val_loss: 0.0049
# Epoch 6/20
# 251/251 [==============================] - 8s 33ms/step - loss: 9.4622e-05 - val_loss: 0.0246
# Epoch 7/20
# 251/251 [==============================] - 9s 37ms/step - loss: 1.0400e-04 - val_loss: 0.0080
# Epoch 8/20
# 251/251 [==============================] - 9s 34ms/step - loss: 8.2009e-05 - val_loss: 0.0115
# Epoch 9/20
# 251/251 [==============================] - 8s 34ms/step - loss: 1.0349e-04 - val_loss: 0.0037
# Epoch 10/20
# 251/251 [==============================] - 9s 35ms/step - loss: 9.0661e-05 - val_loss: 0.0057
# Epoch 11/20
# 251/251 [==============================] - 8s 34ms/step - loss: 8.1097e-05 - val_loss: 0.0167
# Epoch 12/20
# 251/251 [==============================] - 8s 34ms/step - loss: 6.0204e-05 - val_loss: 0.0044
# Epoch 13/20
# 251/251 [==============================] - 9s 38ms/step - loss: 6.2992e-05 - val_loss: 0.0013
# Epoch 14/20
# 251/251 [==============================] - 8s 33ms/step - loss: 5.9420e-05 - val_loss: 0.0018
# Epoch 15/20
# 251/251 [==============================] - 9s 35ms/step - loss: 6.8349e-05 - val_loss: 0.0124
# Epoch 16/20
# 251/251 [==============================] - 9s 35ms/step - loss: 8.4058e-05 - val_loss: 0.0040
# Epoch 17/20
# 251/251 [==============================] - 8s 34ms/step - loss: 6.3038e-05 - val_loss: 0.0025
# Epoch 18/20
# 251/251 [==============================] - 10s 39ms/step - loss: 6.5070e-05 - val_loss: 0.0016
# Epoch 19/20
# 251/251 [==============================] - 8s 34ms/step - loss: 7.1608e-05 - val_loss: 7.6937e-04
# Epoch 20/20
# 251/251 [==============================] - 8s 34ms/step - loss: 4.3333e-05 - val_loss: 0.0041

# %%
grid_search.best_params_
# Out:
# {'batch_size': 16, 'epochs': 20, 'optimizer': 'adam'}

# %%
apple_model2 = grid_search.best_estimator_.model
apple_model2.save('Apple-LSTM-Model-no2.h5')
print('Model is saved to disk :)')
# Out:
# Model is saved to disk :)

# %%
apple_model2 = tf.keras.models.load_model('Apple-2nd-LSTM-Model.h5')
apple_model2.summary()
# Out:
# 2024-09-06 00:09:21.065052: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 00:09:21.067722: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 00:09:21.069345: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 00:09:21.257516: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 00:09:21.258725: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 00:09:21.260178: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "sequential_154"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_308 (LSTM)             (None, 21, 128)           68608
#
#  lstm_309 (LSTM)             (None, 64)                49408
#
#  dense_226 (Dense)           (None, 10)                650
#
#  dense_227 (Dense)           (None, 1)                 11
#
# =================================================================
# Total params: 118,677
# Trainable params: 118,677
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction2 = apple_model2.predict(testX)

print('Prediction Shape', prediction2.shape)
# Out:
# 2024-09-06 17:18:09.426673: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [986,21,5]
# 	 [[{{node Placeholder/_10}}]]
# 2024-09-06 17:18:09.427385: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [986,21,5]
# 	 [[{{node Placeholder/_10}}]]
# 2024-09-06 17:18:09.831331: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 17:18:09.833526: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 17:18:09.836094: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-09-06 17:18:10.130008: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-09-06 17:18:10.132125: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-09-06 17:18:10.134322: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 31/31 [==============================] - 2s 33ms/step
# Prediction Shape (986, 1)

# %%
# Change shape to use inverse_transform
prediction_array2 = np.repeat(prediction2, 5, axis = -1)
original_array = np.repeat(testY, 5, axis = -1)
pred2 = scaler.inverse_transform(np.reshape(prediction_array2,(len(prediction2), 5)))[:,0]
original = scaler.inverse_transform(np.reshape(original_array,(len(testY), 5)))[:,0]
pred2.shape, original.shape
# Out:
# ((986,), (986,))

# %% [markdown]
# ## Model evaluation

# %%
plt.figure(figsize = (14, 6))
sns.set_style('whitegrid')

plt.plot(original, color = 'midnightblue', label = 'Real Price')
plt.plot(pred2, color = 'firebrick', label = 'Predicted Price')
plt.xlabel('Time')
plt.ylabel('Apple Adjusted Closing Price')
plt.title('2nd Model: Stock Price Prediction', fontweight = 'bold', fontsize = 16)
plt.legend()

sns.despine()
plt.show()

# %% [markdown]
# MAE is defined as the average of absolute difference between forecasted values and true values.
#
#
# The MAE does not give larger errors a higher weight, but, when used as a loss function in a machine learning model, it can cause convergence issues during the learning phase.
#
# MAPE is defined as the percentage of the average of absolute difference between forecasted values and true values, divided by true value.

# %%
mae = mean_absolute_error(original, pred2).round(4)

mape = mean_absolute_percentage_error(original, pred2).round(4)

mse = mean_squared_error(original, pred2).round(4)

print(mae, mape)
# Out:
# 7.3558 0.0451

# %%
R2 = r2_score(original, pred2).round(4)

print('R2 score = ', R2)
# Out:
# R2 score =  0.9051

# %%
plt.scatter(original, pred2, s = 75.7, marker = 'o', alpha = 0.25)
plt.plot([min(original), max(original)], [min(pred2), max(pred2)], 'r--')
plt.xlabel('Actual Values', fontweight = 'bold')
plt.ylabel('Predicted Values', fontweight = 'bold')
plt.title(f'R2 Score = {R2:.2f}', fontweight = 'bold', fontsize = 16)
plt.show()

# %% [markdown]
# A MAPE under 10% shows high accuracy, 10-20% shows good forecast results, 20-50% shows reasonable forecast results, and greater than 50% shows incorrect results.

# %%
# initialize list of lists
data = [['2nd Model', mae, mape, R2]]

# Create the pandas DataFrame
df = pd.DataFrame(data, columns=['Model', 'MAE', 'MAPE', 'R2'])

# print dataframe
print(df)
# Out:
#        Model     MAE    MAPE      R2
# 0  2nd Model  3.3832  0.0211  0.9765
